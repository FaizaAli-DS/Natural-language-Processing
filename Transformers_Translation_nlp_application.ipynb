# %% [markdown]
# <a href="https://colab.research.google.com/github/FaizaAli-DS/Natural-language-Processing/blob/all-about-AI-and-Data-Science/Transformers_Translation_nlp_application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install transformers[sentencepiece]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 51.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 32.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.1 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline
text_translator = pipeline("translation_en_to_it", model="Helsinki-NLP/opus-mt-en-it")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
input_text = "This text is translated from English to Italian"

# %%
italian_text = text_translator(input_text, clean_up_tokenization_spaces=True)

# %%
print(italian_text)
# Out:
# [{'translation_text': "Questo testo è tradotto dall'inglese all'italiano"}]

# %%
from transformers import pipeline

text_translator = pipeline("translation_en_to_ur", model="Helsinki-NLP/opus-mt-en-ur")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
urdu_input_text = "This text is translated from English to urdu"

# %%
urdu_text = text_translator(urdu_input_text, clean_up_tokenization_spaces=True)

# %%
print(urdu_text)
# Out:
# [{'translation_text': 'اس متن کا ترجمہ انگریزی سے کِیا گیا ہے ۔'}]
